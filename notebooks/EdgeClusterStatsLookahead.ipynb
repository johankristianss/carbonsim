# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df1 = pd.read_csv('../results/lookahead2/Lulea.csv')
df1['hours'] = df1['tick'] / 3600
df1['cumulative_emission'] = df1['cumulative_emission']

df2 = pd.read_csv('../results/lookahead2/Lulea.csv')
df2['hours'] = df2['tick'] / 3600
df2['utilization'] = df2['utilization'] * 100

df3 = pd.read_csv('../results/lookahead2/Warsaw.csv')
df3['hours'] = df3['tick'] / 3600
df3['cumulative_emission'] = df3['cumulative_emission']

df4 = pd.read_csv('../results/lookahead2/Warsaw.csv')
df4['hours'] = df4['tick'] / 3600
df4['utilization'] = df4['utilization'] * 100

# Create the plot
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot cumulative emissions on the primary y-axis
ax1.plot(df1['hours'], df1['cumulative_emission'], label='Luleå - Emission', color='blue')
ax1.plot(df3['hours'], df3['cumulative_emission'], label='Warsaw - Emission', color='green')
ax1.set_xlabel('Time [hours]')
ax1.set_ylabel('Cumulative Emission [g]', color='black')
ax1.tick_params(axis='y', labelcolor='black')

# Add the secondary y-axis for utilization
ax2 = ax1.twinx()
ax2.plot(df2['hours'], df2['utilization'], label='Luleå - Utilization', color='blue', linestyle='dashed')
ax2.plot(df4['hours'], df4['utilization'], label='Warsaw - Utilization', color='green', linestyle='dashed')
ax2.set_ylabel('Utilization [%]', color='black')
ax2.tick_params(axis='y', labelcolor='black')

# Add legends for both axes
fig.legend(loc='upper left', bbox_to_anchor=(0.1, 0.9))
ax1.grid(True)

# Add a title
plt.title('CO2 Emissions and Utilization Over Time')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df1 = pd.read_csv('../results/lookahead2/Lulea.csv')
df1['hours'] = df1['tick'] / 3600
df1['gpu_utilization'] = df1['gpu_utilization']

df2 = pd.read_csv('../results/lookahead2/Lulea.csv')
df2['hours'] = df2['tick'] / 3600
df2['utilization'] = df2['utilization'] * 100

df3 = pd.read_csv('../results/lookahead2/Warsaw.csv')
df3['hours'] = df3['tick'] / 3600
df3['gpu_utilization'] = df3['gpu_utilization']

df4 = pd.read_csv('../results/lookahead2/Warsaw.csv')
df4['hours'] = df4['tick'] / 3600
df4['utilization'] = df4['utilization'] * 100

# Create the plot
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot cumulative emissions on the primary y-axis
ax1.plot(df1['hours'], df1['gpu_utilization'], label='Luleå - Emission', color='blue')
ax1.plot(df3['hours'], df3['gpu_utilization'], label='Warsaw - Emission', color='green')
ax1.set_xlabel('Time [hours]')
ax1.set_ylabel('GPU Utilization [%]', color='black')
ax1.tick_params(axis='y', labelcolor='black')

# Add the secondary y-axis for utilization
ax2 = ax1.twinx()
ax2.plot(df2['hours'], df2['utilization'], label='Luleå - GPU Utilization', color='blue', linestyle='dashed')
ax2.plot(df4['hours'], df4['utilization'], label='Warsaw - GPU Utilization', color='green', linestyle='dashed')
ax2.set_ylabel('Utilization [%]', color='black')
ax2.tick_params(axis='y', labelcolor='black')

# Add legends for both axes
fig.legend(loc='upper left', bbox_to_anchor=(0.1, 0.9))
ax1.grid(True)

# Add a title
plt.title('GPU Utilization and Utilization Over Time')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df1 = pd.read_csv('../results/lookahead2/Lulea.csv')
df1['hours'] = df1['tick'] / 3600
df1['memory_utilization'] = df1['memory_utilization']

df2 = pd.read_csv('../results/lookahead2/Lulea.csv')
df2['hours'] = df2['tick'] / 3600
df2['utilization'] = df2['utilization'] * 100

df3 = pd.read_csv('../results/lookahead2/Warsaw.csv')
df3['hours'] = df3['tick'] / 3600
df3['memory_utilization'] = df3['memory_utilization']

df4 = pd.read_csv('../results/lookahead2/Warsaw.csv')
df4['hours'] = df4['tick'] / 3600
df4['utilization'] = df4['utilization'] * 100

# Create the plot
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot cumulative emissions on the primary y-axis
ax1.plot(df1['hours'], df1['memory_utilization'], label='Luleå - Emission', color='blue')
ax1.plot(df3['hours'], df3['memory_utilization'], label='Warsaw - Emission', color='green')
ax1.set_xlabel('Time [hours]')
ax1.set_ylabel('Memory Utilization [%]', color='black')
ax1.tick_params(axis='y', labelcolor='black')

# Add the secondary y-axis for utilization
ax2 = ax1.twinx()
ax2.plot(df2['hours'], df2['utilization'], label='Luleå - Memory Utilization', color='blue', linestyle='dashed')
ax2.plot(df4['hours'], df4['utilization'], label='Warsaw - Memory Utilization', color='green', linestyle='dashed')
ax2.set_ylabel('Utilization [%]', color='black')
ax2.tick_params(axis='y', labelcolor='black')

# Add legends for both axes
fig.legend(loc='upper left', bbox_to_anchor=(0.1, 0.9))
ax1.grid(True)

# Add a title
plt.title('Memory utilization and Utilization Over Time')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df1 = pd.read_csv('../results/lookahead2/Lulea.csv')
df1['hours'] = df1['tick'] / 3600
df1['total_gpu_cost'] = df1['totoal_gpu_cost']

df2 = pd.read_csv('../results/lookahead2/Lulea.csv')
df2['hours'] = df2['tick'] / 3600
df2['utilization'] = df2['utilization'] * 100

df3 = pd.read_csv('../results/lookahead2/Warsaw.csv')
df3['hours'] = df3['tick'] / 3600
df3['total_gpu_cost'] = df3['totoal_gpu_cost']

df4 = pd.read_csv('../results/lookahead2/Warsaw.csv')
df4['hours'] = df4['tick'] / 3600
df4['utilization'] = df4['utilization'] * 100

# Create the plot
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot cumulative emissions on the primary y-axis
ax1.plot(df1['hours'], df1['total_gpu_cost'], label='Luleå - GPU Costs', color='blue')
ax1.plot(df3['hours'], df3['total_gpu_cost'], label='Warsaw - GPU Costs', color='green')
ax1.set_xlabel('Time [hours]')
ax1.set_ylabel('GPU Costs [Euro]', color='black')
ax1.tick_params(axis='y', labelcolor='black')

# Add the secondary y-axis for utilization
ax2 = ax1.twinx()
ax2.plot(df2['hours'], df2['utilization'], label='Luleå - Utilization', color='blue', linestyle='dashed')
ax2.plot(df4['hours'], df4['utilization'], label='Warsaw - Utilization', color='green', linestyle='dashed')
ax2.set_ylabel('Utilization [%]', color='black')
ax2.tick_params(axis='y', labelcolor='black')

# Add legends for both axes
fig.legend(loc='upper left', bbox_to_anchor=(0.1, 0.9))
ax1.grid(True)

# Add a title
plt.title('GPU Costs Over Time')

# Show the plot
plt.tight_layout()
plt.show()
