# %%
import matplotlib.pyplot as plt

processes = [{"name": "p_0", "tick": 0, "length": 8010, "cluster": "Lund"}, {"name": "p_1", "tick": 0, "length": 1128, "cluster": "Lund"}, {"name": "p_2", "tick": 0, "length": 7630, "cluster": "Lund"}, {"name": "p_3", "tick": 0, "length": 165, "cluster": "Lund"}, {"name": "p_4", "tick": 171, "length": 61, "cluster": "Lund"}, {"name": "p_5", "tick": 238, "length": 669, "cluster": "Lund"}, {"name": "p_6", "tick": 913, "length": 255, "cluster": "Lund"}, {"name": "p_7", "tick": 1134, "length": 81, "cluster": "Lund"}, {"name": "p_8", "tick": 1174, "length": 2033, "cluster": "Lund"}, {"name": "p_9", "tick": 1221, "length": 1446, "cluster": "Lund"}, {"name": "p_10", "tick": 2673, "length": 34, "cluster": "Lund"}, {"name": "p_11", "tick": 2713, "length": 12312, "cluster": "Lund"}, {"name": "p_12", "tick": 3213, "length": 33, "cluster": "Lund"}, {"name": "p_13", "tick": 3252, "length": 6004, "cluster": "Lund"}, {"name": "p_14", "tick": 7636, "length": 2977, "cluster": "Lund"}, {"name": "p_15", "tick": 8016, "length": 48, "cluster": "Lund"}, {"name": "p_16", "tick": 8070, "length": 5764, "cluster": "Lund"}, {"name": "p_17", "tick": 9262, "length": 672, "cluster": "Lund"}, {"name": "p_18", "tick": 9940, "length": 1521, "cluster": "Lund"}, {"name": "p_19", "tick": 10619, "length": 46, "cluster": "Lund"}, {"name": "p_20", "tick": 10671, "length": 138, "cluster": "Lund"}, {"name": "p_21", "tick": 10815, "length": 333, "cluster": "Lund"}, {"name": "p_22", "tick": 11154, "length": 3507, "cluster": "Lund"}, {"name": "p_23", "tick": 11467, "length": 12896, "cluster": "Lund"}, {"name": "p_24", "tick": 13840, "length": 164, "cluster": "Lund"}, {"name": "p_25", "tick": 14010, "length": 79, "cluster": "Lund"}, {"name": "p_26", "tick": 14095, "length": 36, "cluster": "Lund"}, {"name": "p_27", "tick": 14137, "length": 1739, "cluster": "Lund"}, {"name": "p_28", "tick": 14667, "length": 29970, "cluster": "Lund"}, {"name": "p_29", "tick": 15031, "length": 7907, "cluster": "Lund"}]
#processes = [{"name": "p_0", "tick": 0, "length": 8010, "cluster": "Lund"}, {"name": "p_1", "tick": 0, "length": 1128, "cluster": "Lund"}, {"name": "p_2", "tick": 0, "length": 7630, "cluster": "Lund"}, {"name": "p_3", "tick": 0, "length": 165, "cluster": "Lund"}, {"name": "p_4", "tick": 171, "length": 61, "cluster": "Lund"}, {"name": "p_5", "tick": 238, "length": 669, "cluster": "Lund"}, {"name": "p_6", "tick": 913, "length": 255, "cluster": "Lund"}, {"name": "p_7", "tick": 1134, "length": 81, "cluster": "Lund"}, {"name": "p_8", "tick": 1174, "length": 2033, "cluster": "Lund"}, {"name": "p_9", "tick": 1221, "length": 1446, "cluster": "Lund"}, {"name": "p_10", "tick": 2673, "length": 34, "cluster": "Lund"}, {"name": "p_11", "tick": 2713, "length": 12312, "cluster": "Lund"}, {"name": "p_12", "tick": 3213, "length": 33, "cluster": "Lund"}, {"name": "p_13", "tick": 3252, "length": 6004, "cluster": "Lund"}, {"name": "p_14", "tick": 7636, "length": 2977, "cluster": "Lund"}, {"name": "p_15", "tick": 8016, "length": 48, "cluster": "Lund"}, {"name": "p_16", "tick": 8070, "length": 5764, "cluster": "Lund"}, {"name": "p_17", "tick": 9262, "length": 672, "cluster": "Lund"}, {"name": "p_18", "tick": 9940, "length": 1521, "cluster": "Lund"}, {"name": "p_19", "tick": 10619, "length": 46, "cluster": "Lund"}, {"name": "p_20", "tick": 10671, "length": 138, "cluster": "Lund"}, {"name": "p_21", "tick": 10815, "length": 333, "cluster": "Lund"}, {"name": "p_22", "tick": 11154, "length": 3507, "cluster": "Lund"}, {"name": "p_23", "tick": 11467, "length": 12896, "cluster": "Lund"}, {"name": "p_24", "tick": 13840, "length": 164, "cluster": "Lund"}, {"name": "p_25", "tick": 14010, "length": 79, "cluster": "Lund"}, {"name": "p_26", "tick": 14095, "length": 36, "cluster": "Lund"}, {"name": "p_27", "tick": 14137, "length": 1739, "cluster": "Lund"}, {"name": "p_28", "tick": 14667, "length": 29970, "cluster": "Lund"}, {"name": "p_29", "tick": 15031, "length": 7907, "cluster": "Lund"}, {"name": "p_30", "tick": 15882, "length": 193, "cluster": "Lund"}, {"name": "p_31", "tick": 16081, "length": 380, "cluster": "Lund"}, {"name": "p_32", "tick": 16467, "length": 4378, "cluster": "Lund"}, {"name": "p_33", "tick": 20851, "length": 1350, "cluster": "Lund"}, {"name": "p_34", "tick": 22207, "length": 8643, "cluster": "Lund"}, {"name": "p_35", "tick": 22944, "length": 2107, "cluster": "Lund"}, {"name": "p_36", "tick": 24369, "length": 905, "cluster": "Lund"}, {"name": "p_37", "tick": 25057, "length": 5688, "cluster": "Lund"}, {"name": "p_38", "tick": 25280, "length": 742, "cluster": "Lund"}, {"name": "p_39", "tick": 26028, "length": 74, "cluster": "Lund"}, {"name": "p_40", "tick": 26108, "length": 8642, "cluster": "Lund"}, {"name": "p_41", "tick": 30751, "length": 972, "cluster": "Lund"}, {"name": "p_42", "tick": 30856, "length": 580, "cluster": "Lund"}, {"name": "p_43", "tick": 31442, "length": 5632, "cluster": "Lund"}, {"name": "p_44", "tick": 31729, "length": 1158, "cluster": "Lund"}, {"name": "p_45", "tick": 32893, "length": 4051, "cluster": "Lund"}, {"name": "p_46", "tick": 34756, "length": 89, "cluster": "Lund"}, {"name": "p_47", "tick": 34851, "length": 392, "cluster": "Lund"}, {"name": "p_48", "tick": 35249, "length": 594, "cluster": "Lund"}, {"name": "p_49", "tick": 35849, "length": 4265, "cluster": "Lund"}, {"name": "p_50", "tick": 36950, "length": 45, "cluster": "Lund"}, {"name": "p_51", "tick": 37001, "length": 62, "cluster": "Lund"}, {"name": "p_52", "tick": 37069, "length": 8645, "cluster": "Lund"}, {"name": "p_53", "tick": 37080, "length": 133, "cluster": "Lund"}, {"name": "p_54", "tick": 37219, "length": 4081, "cluster": "Lund"}, {"name": "p_55", "tick": 40120, "length": 447, "cluster": "Lund"}, {"name": "p_56", "tick": 40573, "length": 78, "cluster": "Lund"}, {"name": "p_57", "tick": 40657, "length": 1454, "cluster": "Lund"}, {"name": "p_58", "tick": 41306, "length": 2153, "cluster": "Lund"}, {"name": "p_59", "tick": 42117, "length": 79, "cluster": "Lund"}, {"name": "p_60", "tick": 42202, "length": 11034, "cluster": "Lund"}, {"name": "p_61", "tick": 43465, "length": 6857, "cluster": "Lund"}, {"name": "p_62", "tick": 44643, "length": 5678, "cluster": "Lund"}, {"name": "p_63", "tick": 45720, "length": 127, "cluster": "Lund"}, {"name": "p_64", "tick": 45853, "length": 78, "cluster": "Lund"}, {"name": "p_65", "tick": 45937, "length": 25681, "cluster": "Lund"}, {"name": "p_66", "tick": 50327, "length": 1655, "cluster": "Lund"}, {"name": "p_67", "tick": 50328, "length": 517, "cluster": "Lund"}, {"name": "p_68", "tick": 50851, "length": 2148, "cluster": "Lund"}, {"name": "p_69", "tick": 51988, "length": 1272, "cluster": "Lund"}, {"name": "p_70", "tick": 53005, "length": 71, "cluster": "Lund"}, {"name": "p_71", "tick": 53082, "length": 177, "cluster": "Lund"}, {"name": "p_72", "tick": 53242, "length": 647, "cluster": "Lund"}, {"name": "p_73", "tick": 53265, "length": 3363, "cluster": "Lund"}, {"name": "p_74", "tick": 53266, "length": 4245, "cluster": "Lund"}, {"name": "p_75", "tick": 53895, "length": 8809, "cluster": "Lund"}, {"name": "p_76", "tick": 56634, "length": 741, "cluster": "Lund"}, {"name": "p_77", "tick": 57381, "length": 89, "cluster": "Lund"}, {"name": "p_78", "tick": 57476, "length": 1535, "cluster": "Lund"}, {"name": "p_79", "tick": 57517, "length": 1190, "cluster": "Lund"}, {"name": "p_80", "tick": 58713, "length": 549, "cluster": "Lund"}, {"name": "p_81", "tick": 59017, "length": 1184, "cluster": "Lund"}, {"name": "p_82", "tick": 59268, "length": 1711, "cluster": "Lund"}, {"name": "p_83", "tick": 60207, "length": 59, "cluster": "Lund"}, {"name": "p_84", "tick": 60272, "length": 1296, "cluster": "Lund"}, {"name": "p_85", "tick": 60985, "length": 601, "cluster": "Lund"}, {"name": "p_86", "tick": 61574, "length": 1025, "cluster": "Lund"}, {"name": "p_87", "tick": 61592, "length": 1280, "cluster": "Lund"}, {"name": "p_88", "tick": 62605, "length": 1159, "cluster": "Lund"}, {"name": "p_89", "tick": 62710, "length": 69, "cluster": "Lund"}, {"name": "p_90", "tick": 62785, "length": 402, "cluster": "Lund"}, {"name": "p_91", "tick": 62878, "length": 17101, "cluster": "Lund"}, {"name": "p_92", "tick": 63193, "length": 47, "cluster": "Lund"}, {"name": "p_93", "tick": 63246, "length": 1363, "cluster": "Lund"}, {"name": "p_94", "tick": 63770, "length": 4324, "cluster": "Lund"}, {"name": "p_95", "tick": 64615, "length": 8865, "cluster": "Lund"}, {"name": "p_96", "tick": 68100, "length": 1350, "cluster": "Lund"}, {"name": "p_97", "tick": 69456, "length": 8645, "cluster": "Lund"}, {"name": "p_98", "tick": 71624, "length": 133, "cluster": "Lund"}, {"name": "p_99", "tick": 71763, "length": 38, "cluster": "Lund"}, {"name": "p_100", "tick": 71807, "length": 32, "cluster": "Lund"}, {"name": "p_101", "tick": 71845, "length": 293, "cluster": "Lund"}, {"name": "p_102", "tick": 72144, "length": 4068, "cluster": "Lund"}, {"name": "p_103", "tick": 73486, "length": 127, "cluster": "Lund"}, {"name": "p_104", "tick": 73619, "length": 4321, "cluster": "Lund"}, {"name": "p_105", "tick": 76218, "length": 3665, "cluster": "Lund"}, {"name": "p_106", "tick": 77946, "length": 1315, "cluster": "Lund"}, {"name": "p_107", "tick": 78107, "length": 41, "cluster": "Lund"}, {"name": "p_108", "tick": 78154, "length": 85, "cluster": "Lund"}, {"name": "p_109", "tick": 78245, "length": 89, "cluster": "Lund"}, {"name": "p_110", "tick": 78340, "length": 181, "cluster": "Lund"}, {"name": "p_111", "tick": 78527, "length": 3016, "cluster": "Lund"}, {"name": "p_112", "tick": 79267, "length": 1543, "cluster": "Lund"}, {"name": "p_113", "tick": 79889, "length": 10563, "cluster": "Lund"}, {"name": "p_114", "tick": 79985, "length": 4325, "cluster": "Lund"}, {"name": "p_115", "tick": 80816, "length": 96, "cluster": "Lund"}, {"name": "p_116", "tick": 80918, "length": 118, "cluster": "Lund"}, {"name": "p_117", "tick": 81042, "length": 105, "cluster": "Lund"}, {"name": "p_118", "tick": 81153, "length": 8641, "cluster": "Lund"}, {"name": "p_119", "tick": 81549, "length": 11411, "cluster": "Lund"}, {"name": "p_120", "tick": 84316, "length": 43201, "cluster": "Lund"}]
processes = [{"name": "p_0", "tick": 0, "length": 8010, "cluster": "Lund"}, {"name": "p_1", "tick": 0, "length": 1128, "cluster": "Lund"}, {"name": "p_2", "tick": 0, "length": 7630, "cluster": "Lund"}, {"name": "p_3", "tick": 0, "length": 165, "cluster": "Lund"}, {"name": "p_4", "tick": 171, "length": 61, "cluster": "Lund"}, {"name": "p_5", "tick": 238, "length": 669, "cluster": "Lund"}, {"name": "p_6", "tick": 913, "length": 255, "cluster": "Lund"}, {"name": "p_7", "tick": 1134, "length": 81, "cluster": "Lund"}, {"name": "p_8", "tick": 1174, "length": 2033, "cluster": "Lund"}, {"name": "p_9", "tick": 1221, "length": 1446, "cluster": "Lund"}, {"name": "p_10", "tick": 2673, "length": 34, "cluster": "Lund"}, {"name": "p_11", "tick": 2713, "length": 12312, "cluster": "Lund"}, {"name": "p_12", "tick": 3213, "length": 33, "cluster": "Lund"}, {"name": "p_13", "tick": 3252, "length": 6004, "cluster": "Lund"}, {"name": "p_14", "tick": 7636, "length": 2977, "cluster": "Lund"}]
procesess = [{"name": "p_0", "tick": 0, "length": 8010, "cluster": "Lund"}, {"name": "p_1", "tick": 8016, "length": 1128, "cluster": "Lund"}, {"name": "p_2", "tick": 9150, "length": 7630, "cluster": "Lund"}, {"name": "p_3", "tick": 16786, "length": 165, "cluster": "Lund"}, {"name": "p_4", "tick": 16957, "length": 61, "cluster": "Lund"}, {"name": "p_5", "tick": 17024, "length": 669, "cluster": "Lund"}, {"name": "p_6", "tick": 17699, "length": 255, "cluster": "Lund"}, {"name": "p_7", "tick": 17960, "length": 81, "cluster": "Lund"}, {"name": "p_8", "tick": 18047, "length": 2033, "cluster": "Lund"}, {"name": "p_9", "tick": 20086, "length": 1446, "cluster": "Lund"}, {"name": "p_10", "tick": 21538, "length": 34, "cluster": "Lund"}, {"name": "p_11", "tick": 21578, "length": 12312, "cluster": "Lund"}, {"name": "p_12", "tick": 33896, "length": 33, "cluster": "Lund"}, {"name": "p_13", "tick": 33935, "length": 6004, "cluster": "Lund"}, {"name": "p_14", "tick": 39945, "length": 2977, "cluster": "Lund"}]
procesess = [{"name": "p_0", "tick": 0, "length": 8010, "cluster": "Lund"}, {"name": "p_1", "tick": 0, "length": 1128, "cluster": "Lund"}, {"name": "p_2", "tick": 1134, "length": 7630, "cluster": "Lund"}, {"name": "p_3", "tick": 8016, "length": 165, "cluster": "Lund"}, {"name": "p_4", "tick": 8187, "length": 61, "cluster": "Lund"}, {"name": "p_5", "tick": 8254, "length": 669, "cluster": "Lund"}, {"name": "p_6", "tick": 8770, "length": 255, "cluster": "Lund"}, {"name": "p_7", "tick": 8929, "length": 81, "cluster": "Lund"}, {"name": "p_8", "tick": 9016, "length": 2033, "cluster": "Lund"}, {"name": "p_9", "tick": 9031, "length": 1446, "cluster": "Lund"}, {"name": "p_10", "tick": 10483, "length": 34, "cluster": "Lund"}, {"name": "p_11", "tick": 10523, "length": 12312, "cluster": "Lund"}, {"name": "p_12", "tick": 11055, "length": 33, "cluster": "Lund"}, {"name": "p_13", "tick": 11094, "length": 6004, "cluster": "Lund"}, {"name": "p_14", "tick": 17104, "length": 2977, "cluster": "Lund"}]
processes = [{"name": "p_0", "tick": 0, "length": 8010, "cluster": "Lund"}, {"name": "p_1", "tick": 0, "length": 1128, "cluster": "Lund"}, {"name": "p_2", "tick": 1134, "length": 7630, "cluster": "Lund"}, {"name": "p_3", "tick": 8016, "length": 165, "cluster": "Lund"}, {"name": "p_4", "tick": 8187, "length": 61, "cluster": "Lund"}, {"name": "p_5", "tick": 8254, "length": 669, "cluster": "Lund"}, {"name": "p_6", "tick": 8770, "length": 255, "cluster": "Lund"}, {"name": "p_7", "tick": 8929, "length": 81, "cluster": "Lund"}, {"name": "p_8", "tick": 9016, "length": 2033, "cluster": "Lund"}, {"name": "p_9", "tick": 9031, "length": 1446, "cluster": "Lund"}]
processes = [{"name": "p_0", "tick": 0, "length": 8010, "cluster": "Lund"}, {"name": "p_1", "tick": 0, "length": 1128, "cluster": "Lund"}, {"name": "p_2", "tick": 1134, "length": 7630, "cluster": "Lund"}, {"name": "p_3", "tick": 8016, "length": 165, "cluster": "Lund"}, {"name": "p_4", "tick": 8187, "length": 61, "cluster": "Lund"}, {"name": "p_5", "tick": 8254, "length": 669, "cluster": "Lund"}, {"name": "p_6", "tick": 8770, "length": 255, "cluster": "Lund"}, {"name": "p_7", "tick": 8929, "length": 81, "cluster": "Lund"}, {"name": "p_8", "tick": 9016, "length": 2033, "cluster": "Lund"}, {"name": "p_9", "tick": 9031, "length": 1446, "cluster": "Lund"}, {"name": "p_10", "tick": 10483, "length": 34, "cluster": "Lund"}, {"name": "p_11", "tick": 10523, "length": 12312, "cluster": "Lund"}, {"name": "p_12", "tick": 11055, "length": 33, "cluster": "Lund"}, {"name": "p_13", "tick": 11094, "length": 6004, "cluster": "Lund"}, {"name": "p_14", "tick": 17104, "length": 2977, "cluster": "Lund"}]
# Plotting
fig, ax = plt.subplots(figsize=(12, 8))

for i, process in enumerate(processes):
    start = process["tick"]
    length = process["length"]
    ax.broken_barh([(start, length)], (i, 0.8), facecolors='tab:blue')
    ax.text(start, i + 0.4, process["name"], verticalalignment='center', fontsize=8, color='black')

# Formatting
ax.set_xlabel("Time (ticks)")
ax.set_ylabel("Processes")
ax.set_yticks(range(len(processes)))
ax.set_yticklabels([p["name"] for p in processes])
ax.set_title("Process Execution Timeline")
ax.grid(True, axis='x', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
import os
# Conversion factor from ticks to hours
ticks_to_hours = 3600

# Plotting
fig, ax = plt.subplots(figsize=(8, 6))

for i, process in enumerate(processes):
    start = process["tick"] / ticks_to_hours
    length = process["length"] / ticks_to_hours
    ax.broken_barh([(start, length)], (i, 0.8), facecolors='tab:blue')
    ax.text(start, i + 0.4, process["name"], verticalalignment='center', fontsize=8, color='black')

# Formatting
ax.set_xlabel("Time (hours)", fontsize=16)
ax.set_ylabel("Processes", fontsize=16)
ax.set_yticks(range(len(processes)))
ax.set_yticklabels([p["name"] for p in processes])
ax.set_title("Processes Reservation Layout", color='black', fontsize=16, fontweight='bold')
ax.grid(True, axis='x', linestyle='--', alpha=0.7)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()

output_image_path = os.path.join("layout.png")
plt.savefig(output_image_path, dpi=300, bbox_inches='tight')  

plt.show()

# %%
# Find overlapping processes
overlapping_processes = []

for i, process1 in enumerate(processes):
    start1 = process1["tick"]
    end1 = start1 + process1["length"]
    for j, process2 in enumerate(processes):
        if i != j:
            start2 = process2["tick"]
            end2 = start2 + process2["length"]
            if start1 < end2 and start2 < end1:  # Check for overlap
                overlapping_processes.append((process1["name"], process2["name"]))

# Remove duplicates from overlapping_processes
overlapping_processes = list(set(tuple(sorted(pair)) for pair in overlapping_processes))
print(overlapping_processes)
# Out:
# [('p_23', 'p_25'), ('p_18', 'p_19'), ('p_22', 'p_25'), ('p_0', 'p_6'), ('p_2', 'p_4'), ('p_27', 'p_28'), ('p_1', 'p_6'), ('p_11', 'p_19'), ('p_16', 'p_22'), ('p_14', 'p_16'), ('p_2', 'p_3'), ('p_0', 'p_11'), ('p_16', 'p_18'), ('p_23', 'p_26'), ('p_23', 'p_24'), ('p_22', 'p_26'), ('p_22', 'p_24'), ('p_16', 'p_20'), ('p_0', 'p_1'), ('p_18', 'p_22'), ('p_0', 'p_2'), ('p_11', 'p_12'), ('p_2', 'p_5'), ('p_7', 'p_8'), ('p_23', 'p_28'), ('p_1', 'p_2'), ('p_0', 'p_3'), ('p_11', 'p_27'), ('p_18', 'p_20'), ('p_11', 'p_13'), ('p_11', 'p_22'), ('p_0', 'p_7'), ('p_11', 'p_18'), ('p_0', 'p_10'), ('p_11', 'p_23'), ('p_13', 'p_14'), ('p_0', 'p_9'), ('p_12', 'p_2'), ('p_11', 'p_20'), ('p_0', 'p_4'), ('p_13', 'p_15'), ('p_11', 'p_8'), ('p_13', 'p_16'), ('p_14', 'p_17'), ('p_11', 'p_14'), ('p_16', 'p_21'), ('p_1', 'p_4'), ('p_10', 'p_8'), ('p_13', 'p_2'), ('p_2', 'p_6'), ('p_11', 'p_15'), ('p_28', 'p_29'), ('p_27', 'p_29'), ('p_11', 'p_25'), ('p_0', 'p_12'), ('p_18', 'p_21'), ('p_1', 'p_3'), ('p_2', 'p
# ...
